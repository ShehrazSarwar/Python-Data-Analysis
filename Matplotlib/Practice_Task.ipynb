# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

plt.style.use('default')

# %% [markdown]
# ## `Problem 1 to 5`:
#
# Dataset link: https://tinyurl.com/2fe6vz4u
#
# **Add a label to every axis and add a proper title for the charts. Also add proper labels if there are multiple representations.** Then, you can customize it as your wish.
#
# ### **`Problem-1:`** Draw a line plot of which, the x-axis is the "Year" and the y-axis is sum of "PM2.5" of two countries Iran and China.

# %%
# code here
df = pd.read_csv('https://tinyurl.com/2fe6vz4u')
df.head()
# Out:
#    Unnamed: 0  Position Country  City/Town  Year  PM2.5 Temporal coverage  \
# 0           0         1   India     Kanpur  2016    173              >75%
# 1           1         2   India  Faridabad  2016    172              >75%
# 2           2         3   India       Gaya  2016    149        50% -< 75%
# 3           3         4   India   Varanasi  2016    146              >75%
# 4           4         5   India      Patna  2016    144              >75%
#
#    PM10 Temporal coverage.1  Database version (year)
# 0   319                 NaN                     2018
# 1   316                 NaN                     2018
# 2   275                 NaN                     2018
# 3   260                 NaN                     2018
# 4   266                 NaN                     2018

# %%
iran_df = df[df['Country'] == "Iran"].groupby('Year',as_index=False)['PM2.5'].sum()
china_df = df[df['Country'] == "China"].groupby('Year',as_index=False)['PM2.5'].sum()

# %%
plt.plot(iran_df['Year'],iran_df['PM2.5'], label='Iran',linestyle='dashdot')
plt.plot(china_df['Year'],china_df['PM2.5'], label='China',color='Red')
plt.xticks(df['Year'].unique())
plt.xlabel('Year')
plt.ylabel('PM2.5')
plt.title('PM2.5 Over the years')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### **`Problem-2:`** Draw a histogram of the  column "PM10" of which the y-axis represents the probability (see the documentation how to draw the probability).

# %%
# code here
plt.hist(df['PM10'],density=True,color='Orange',bins=20,edgecolor='black')
plt.xlabel('Bins')
plt.ylabel('Probability')
plt.title('Histogram of PM10')
plt.show()

# %% [markdown]
# ### **`Problem-3:`** Draw a scatter plot where x-axis represents "PM2.5" and y-axis represents "PM10" for two countries Poland and Chile.

# %%
# code here
chile_df = df.query("Country == 'Chile'")
poland_df = df.query("Country == 'Poland'")

# %%
plt.scatter(chile_df['PM2.5'],chile_df['PM10'],marker="+",color='red',label='Chile')
plt.scatter(poland_df['PM2.5'],poland_df['PM10'],marker="D",color='black',label='Poland')
plt.xlabel('PM2.5')
plt.ylabel('PM10')
plt.title('PM2.5 Vs PM10 for Chile and Poland')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-4:`** Draw a pie chart of top 5 most frequent countries.

# %%
# code here
temp_df = df['Country'].value_counts().head()
plt.pie(temp_df,labels=temp_df.index.values,autopct='%0.1f%%')
plt.title('Pie chart of top 5 most frequent countries.')
plt.show()

# %% [markdown]
# ### **`Problem-5:`** Draw a bar chart which represents the counts of top 5 most frequent countries.

# %%
plt.bar(temp_df.index.values,temp_df)
plt.title('Pie chart of top 5 most frequent countries.')
plt.ylabel('Count')
plt.xlabel('Country')
plt.show()

# %% [markdown]
# ##`Problem 6-10`
# Data Set - https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv
#
# This is a Sales data of any company in a Year.
#
#
# ###`Problem-6`
# Show a line plot of Total Profit for each month with below styling.
# * Dotted Line
# * Line Color Blue
# * Show Legend at top left
# * Circle Marker

# %%
# code here
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
plt.plot(df['month_number'],df['total_profit'],color='blue',linestyle='dotted',marker='o',label='Total Profit For Each Month')
plt.xlabel('Month')
plt.ylabel('Total Profit')
plt.xticks(df['month_number'])
plt.title('Company sales profit')
plt.legend(loc="upper left")
plt.grid()
plt.show()

# %% [markdown]
# ###`Problem-7`
# Show sales of each product in march month as pie chart.
# * Show Percentage value
# * Give Title "Sales in March"
# * Explode ToothPaste with shadow

# %%
march_df = df.query('month_number == 3')
march_df = march_df.iloc[:,1:7].transpose()
march_df
# Out:
#                 2
# facecream    2140
# facewash     1340
# toothpaste   4550
# bathingsoap  9550
# shampoo      3550
# moisturizer  1340

# %%
# code here
plt.pie(march_df[2], labels=march_df.index.values,
        autopct='%0.1f%%', explode=[0,0,0.1,0,0,0], shadow=True)
plt.title('Sales of each product in march')
plt.show()

# %% [markdown]
# ###`Problem-8` Multiline Plot of all products sales.
# * Give different styes for each products
# * Add legend at top right

# %%
# code here
plt.plot(df['month_number'], df['facecream'],   label = 'Face cream', linestyle='dotted', marker='o', linewidth=3)
plt.plot(df['month_number'], df['toothpaste'], label = 'Tooth Paste', marker='o', linewidth=3)
plt.plot(df['month_number'], df['bathingsoap'], label = 'Bathing Soap', marker='o', linewidth=3)
plt.plot(df['month_number'], df['shampoo'], label = 'Shampoo', linestyle='dashdot', linewidth=3)
plt.plot(df['month_number'], df['moisturizer'], label = 'Moisturizer', marker='D', linewidth=3)
plt.plot(df['month_number'], df['facewash'],   label = 'Face Wash',  linestyle='dashed', linewidth=2)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper right')
plt.xticks(df['month_number'])
plt.title('Sales data')
plt.show()

# %% [markdown]
# ###`Problem-9` Show Quarter wise Sales data for all products as multi Bar chart.

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit  date
# 0          1500        21100        211000     1
# 1          1200        18330        183300     1
# 2          1340        22470        224700     1
# 3          1130        22270        222700     2
# 4          1740        20960        209600     2
# 5          1555        20140        201400     2
# 6          1120        29550        295500     3
# 7          1400        36140        361400     3
# 8          1780        23400        234000     3
# 9          1890        26670        266700     4
# 10         2100        41280        412800     4
# 11         1760        30020        300200     4

# %%
# code here
df['date'] = pd.to_datetime(df['month_number'],format='%m')
df['date'] = df['date'].dt.quarter
new_df = df.groupby(df['date']).sum()
i = -1
for col in new_df.columns[1:7]:
  plt.bar(new_df.index + i, new_df[col], width=0.15, label=col)
  i = i - 0.15

plt.xticks(new_df.index - 1.38, new_df.index)
plt.title('Quarter Wise Sales')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# ###`Problem-10` Plot Stacked Bar chart quarter wise for each product.

# %%
# code here
new_df
# Out:
#       month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# date
# 1                6       7270      4040       14850        24850     6850
# 2               15       9760      4425       15320        24120     5320
# 3               24      10220      4300       16740        27040     6740
# 4               33       7230      5750       23000        38000     6500
#
#       moisturizer  total_units  total_profit
# date
# 1            4040        61900        619000
# 2            4425        63370        633700
# 3            4300        89090        890900
# 4            5750        97970        979700

# %%
sum_cols = []
for col in new_df.columns[1:7]:
  if(len(sum_cols) == 0):
    plt.bar(new_df.index, new_df[col], label=col)
  else:
    plt.bar(new_df.index, new_df[col], bottom=sum(sum_cols), label=col)
  sum_cols.append(new_df[col])
plt.xticks(new_df.index)
plt.title('Quarter Wise Stacked Bar Chart')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.legend()
plt.show()
