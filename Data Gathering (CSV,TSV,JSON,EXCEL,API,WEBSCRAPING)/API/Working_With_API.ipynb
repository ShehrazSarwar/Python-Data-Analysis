# %%
import pandas as pd
import requests

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiMTA1ODJhYWNhNTZlZGVkMThhNDBjYjkyNDQyZDIzZiIsIm5iZiI6MTc1ODU4MDQ2Mi42LCJzdWIiOiI2OGQxY2VlZTc3NWMyNjZlYTNjYzNjYjAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.2YJeC_Y1lSOilh3V2JWu3jL2uxSHO2GdlRlxjN-3poI"
}

response = requests.get(url, headers=headers)

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     28.5814
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     30.7040
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     15.6700
# 3  The true story of how businessman Oskar Schind...   1993-12-15     15.4034
# 4  The defense and the prosecution have rested an...   1957-04-10     13.7100
#
#    vote_average  vote_count
# 0         8.712       28901
# 1         8.685       21846
# 2         8.570       13194
# 3         8.566       16716
# 4         8.500        9407

# %%
dfs = []

# %%
for i in range(1,501):
  url = f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={i}"
  response = requests.get(url, headers=headers)
  temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
  dfs.append(temp_df)
df = pd.concat(dfs,ignore_index=True)

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 9998    9405               Double Team
# 9999   13788                The Unborn
# 16788   8839                    Casper
# 29444   7233                   Rebound
# 29447  10802                 Showgirls
#
#                                                 overview release_date  \
# 0      Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2      In the continuing saga of the Corleone crime f...   1974-12-20
# 3      The true story of how businessman Oskar Schind...   1993-12-15
# 4      The defense and the prosecution have rested an...   1957-04-10
# ...

# %%
df.to_csv('movies.csv',index=False)
