# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Colored Scatter Plot

# %%
iris = pd.read_csv('/content/drive/MyDrive/Python_Adv/Data Analysis/Matplotlib/datasets-session-24/iris.csv')
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 101  102            5.8           2.7            5.1           1.9
# 107  108            7.3           2.9            6.3           1.8
# 149  150            5.9           3.0            5.1           1.8
# 77    78            6.7           3.0            5.0           1.7
# 135  136            7.7           3.0            6.1           2.3
#
#              Species
# 101   Iris-virginica
# 107   Iris-virginica
# 149   Iris-virginica
# 77   Iris-versicolor
# 135   Iris-virginica

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
color_map = {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}
# cmap to change color style and alpha for opactiy (0-1 range) 1 is default
# c for colors
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c= iris['Species'].map(color_map),cmap= 'plasma',alpha= 1)
plt.xlabel('SepalLengthCm')
plt.ylabel('PetalLengthCm')
plt.title('Colored Plot Of Sepal and Petal Length')
plt.colorbar()
plt.show()

# %% [markdown]
# ### Plot Size

# %%
plt.figure(figsize=(15,7))
color_map = {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}
# cmap to change color style and alpha for opactiy (0-1 range) 1 is default
# c for colors
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c= iris['Species'].map(color_map),cmap= 'plasma',alpha= 1)
plt.xlabel('SepalLengthCm')
plt.ylabel('PetalLengthCm')
plt.title('Colored Plot Of Sepal and Petal Length')
plt.colorbar()
plt.show()

# %% [markdown]
# ### Annotations

# %%
batter = pd.read_csv('/content/drive/MyDrive/Python_Adv/Data Analysis/Matplotlib/datasets-session-24/batter.csv')
df = batter.head(100).sample(25,random_state=5).reset_index(drop=True)
df
# Out:
#            batter  runs        avg  strike_rate
# 0       KH Pandya  1326  22.100000   132.203390
# 1        SE Marsh  2489  39.507937   130.109775
# 2       JP Duminy  2029  39.784314   120.773810
# 3        SA Yadav  2644  29.707865   134.009123
# 4       IK Pathan  1150  21.698113   116.751269
# 5      JC Buttler  2832  39.333333   144.859335
# 6       G Gambhir  4217  31.007353   119.665153
# 7     BB McCullum  2882  27.711538   126.848592
# 8      KA Pollard  3437  28.404959   140.457703
# 9         WP Saha  2427  25.281250   124.397745
# 10  ST Jayasuriya   768  27.428571   134.031414
# 11     MA Agarwal  2335  22.669903   129.506378
# 12       DJ Hooda  1237  20.278689   127.525773
# 13         N Rana  2181  27.961538   130.053667
# 14      SS Tiwary  1494  28.730769   115.724245
# 15      JH Kallis  2427  28.552941   105.936272
# 16  KS Williamson  2105  36.293103   123.315759
# 17       DJ Bravo  1560  22.608696   125.100241
# 18      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['avg'],df['strike_rate'],s=df['runs'])
for i in range(len(df)):
  plt.text(df['avg'].iloc[i],df['strike_rate'].iloc[i],s=df['batter'].iloc[i],fontdict={'color':'brown','size':9})

plt.title('Avg VS Strike Rate')
plt.xlabel('Avg')
plt.ylabel('Strike Rate')
plt.show()

# %% [markdown]
# ### Horizontal & Vertical Lines

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['avg'],df['strike_rate'],s=df['runs'])
for i in range(len(df)):
  plt.text(df['avg'].iloc[i],df['strike_rate'].iloc[i],s=df['batter'].iloc[i],fontdict={'color':'brown','size':9})

plt.axhline(130,color='red')
plt.axvline(30,color='orange')
plt.title('Avg VS Strike Rate')
plt.xlabel('Avg')
plt.ylabel('Strike Rate')
plt.show()

# %% [markdown]
# ### Sub Plots

# %%
batter.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
# different way to plot graphs
fig, ax = plt.subplots(figsize=(8,5))
ax.scatter(batter['avg'],batter['strike_rate'],color='red',marker='+')
ax.set_title('Test')
ax.set_xlabel('Avg')
ax.set_ylabel('Strike Rate')
fig.show()

# %%
sample_df = pd.read_csv('/content/drive/MyDrive/Python_Adv/Data Analysis/Matplotlib/datasets-session-24/batsman_season_record.csv')
sample_df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
fig, ax = plt.subplots()
x = np.arange(len(sample_df))
ax.bar(x - 0.2,sample_df['2015'],label = '2015',width = 0.2)
ax.bar(x ,sample_df['2016'],label = '2016',width = 0.2,color='orange')
ax.bar(x + 0.2,sample_df['2017'],label = '2017',width = 0.2,color='red')
ax.set_xticks(x)
ax.set_xticklabels(sample_df['batsman'])
ax.set_title('batsman season record')
ax.set_ylabel('Runs')
ax.set_xlabel('Batsman')
plt.legend()
fig.show()

# %%
fig, ax = plt.subplots(2,1,sharex=True,figsize=(8,5))
ax[0].scatter(batter['avg'],batter['strike_rate'],color='red',marker='+')
ax[0].set_ylabel('Strike Rate')
ax[0].set_title('Avg Vs Strike Rate')

ax[1].scatter(batter['avg'],batter['runs'])
ax[1].set_ylabel('Runs')
ax[1].set_title('Avg Vs Runs')
ax[1].set_xlabel('Avg')
# Out:
# Text(0.5, 0, 'Avg')

# %%
fig, ax = plt.subplots(2,2,figsize=(8,8))
ax[0,0].scatter(batter['avg'],batter['strike_rate'],color='red',marker='+')
ax[1,0].hist(batter['avg'],color='purple')
ax[0,1].scatter(batter['avg'],batter['runs'])
ax[1,1].bar(batter['batter'].iloc[:5],batter['runs'].iloc[:5],color=['orange','red','blue','green','purple'])
ax[1,1].set_xticks(batter['batter'].iloc[:5])
ax[1,1].set_xticklabels(batter['batter'].iloc[:5],rotation=40)
fig.show()

# %% [markdown]
# ### 3D Scatter Plot

# %%
fig = plt.figure()
ax = plt.subplot(projection = '3d')
ax.scatter3D(df['avg'], df['strike_rate'],df['runs'])
fig.show()

# %% [markdown]
# ### 3D Line Plot

# %%
x = [10,20,30,40]
y = [6,12.5,55,9]
z = [50,78,66,44]
fig = plt.figure()
ax = plt.subplot(projection = '3d')
ax.plot3D(x,y,z,color='red',marker='D')
fig.show()

# %% [markdown]
# ### 3D Surface Plot

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)
xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2
fig = plt.figure()
ax = plt.subplot(projection = '3d')
p = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)
fig.show()

# %% [markdown]
# ### Contour Plots

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)
xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2

fig = plt.figure()
ax = plt.subplot()
p = ax.contour(xx,yy,z,cmap='viridis')
fig.colorbar(p)
fig.show()

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)
xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2

fig = plt.figure()
ax = plt.subplot()
p = ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(p)
fig.show()

# %% [markdown]
# ### Matplotlib Heatmap ---> Numerical Data

# %%
delivery = pd.read_csv('/content/drive/MyDrive/Python_Adv/Data Analysis/Matplotlib/datasets-session-24/IPL_Ball_by_Ball_2008_2022.csv')
delivery.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
df = delivery[(delivery['ballnumber'].isin([1,2,3,4,5,6])) & (delivery['batsman_run'] == 6)]

# %%
grid_df = df.pivot_table(index='overs', columns='ballnumber', values='batsman_run',aggfunc='count')
grid_df
# Out:
# ballnumber    1    2    3    4    5    6
# overs
# 0             9   17   31   39   33   27
# 1            31   40   49   56   58   54
# 2            75   62   70   72   58   76
# 3            60   74   74  103   74   71
# 4            71   76  112   80   81   72
# 5            77  102   63   86   78   80
# 6            34   56   49   59   64   38
# 7            59   62   73   70   69   56
# 8            86   83   79   81   73   52
# 9            54   62   86   61   74   67
# 10           82   92   83   69   72   70
# 11           91   72   87   79   87   70
# 12           87  109   79  100  100   84
# 13          101  101   99   97   90   88
# 14           90  124  103  100   86  106
# 15          102  120  129  121  113   96
# 16          107  115  111  100  120  101
# 17          126  142  137  151  117  129
# 18          118  114  151  132  138  128
# 19          136  120  151  151  116  148

# %%
plt.figure(figsize=(6,6))
plt.imshow(grid_df)
plt.yticks(grid_df.index,grid_df.index + 1)
plt.xticks(range(6),range(1,7))
plt.colorbar()
plt.title("Ball By Ball Analysis Of Sixes",fontdict={'family':'monospace','size':10,})
plt.xlabel('Ball No')
plt.ylabel('Over No')
plt.show()

# %% [markdown]
# ### Pandas Plot Function

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_copy = tips.copy()
tips_copy['size'] = tips_copy['size'] * 100
tips_copy.plot(kind='scatter',x='total_bill',title='Cost Analysis',y='tip',marker='+',s='size',c='sex',cmap='viridis')
# Out:
# <Axes: title={'center': 'Cost Analysis'}, xlabel='total_bill', ylabel='tip'>

# %%
stocks = pd.read_csv('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv')
stocks.head()
# Out:
#          Date        MSFT          FB        AAPL
# 0  2021-05-24  249.679993  328.730011  124.610001
# 1  2021-05-31  250.789993  330.350006  125.889999
# 2  2021-06-07  257.890015  331.260010  127.349998
# 3  2021-06-14  259.429993  329.660004  130.460007
# 4  2021-06-21  265.019989  341.369995  133.110001

# %%
stocks.plot(kind='line',x='Date',rot=35)
# Out:
# <Axes: xlabel='Date'>

# %%
stocks[['AAPL','Date']].plot(kind='line',x='Date',rot=45)
# Out:
# <Axes: xlabel='Date'>

# %%
stocks.plot(kind='line',x='Date',rot=35,subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
sample_df.plot(kind='bar',y='2015',x='batsman',rot=0)
# Out:
# <Axes: xlabel='batsman'>

# %%
sample_df.plot(kind='bar',x='batsman',rot=0)
# Out:
# <Axes: xlabel='batsman'>

# %%
sample_df.plot(kind='bar',x='batsman',stacked=True,rot=0)
# Out:
# <Axes: xlabel='batsman'>

# %%
stocks.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sample_df[['2015','2016','2017']].plot(labels=sample_df['batsman'],kind='pie',subplots=True,figsize=(25,18),autopct='%0.1f%%')
# Out:
# array([<Axes: ylabel='2015'>, <Axes: ylabel='2016'>,
#        <Axes: ylabel='2017'>], dtype=object)

# %%
sample_df[['2015']].plot(labels=sample_df['batsman'],kind='pie',subplots=True,autopct='%0.1f%%',figsize=(6,6))
# Out:
# array([<Axes: ylabel='2015'>], dtype=object)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_ = tips.pivot_table(index=['day','time'],columns=['sex','smoker'],values='total_bill',aggfunc='mean',observed=True)
tips_
# Out:
# sex               Male                Female
# smoker             Yes         No        Yes         No
# day  time
# Thur Lunch   19.171000  18.486500  19.218571  15.899167
#      Dinner        NaN        NaN        NaN  18.780000
# Fri  Lunch   11.386667        NaN  13.260000  15.980000
#      Dinner  25.892000  17.475000  12.200000  22.750000
# Sat  Dinner  21.837778  19.929063  20.266667  19.003846
# Sun  Dinner  26.141333  20.403256  16.540000  20.824286

# %%
tips_.plot(kind='bar',rot=45)
# Out:
# <Axes: xlabel='day,time'>

# %%
tips_.plot(kind='pie',subplots=True,figsize=(25,18),autopct='%0.1f%%',shadow=True)
# Out:
# array([<Axes: ylabel='(Male, Yes)'>, <Axes: ylabel='(Male, No)'>,
#        <Axes: ylabel='(Female, Yes)'>, <Axes: ylabel='(Female, No)'>],
#       dtype=object)

# %%
tips_.plot(kind='line',rot=45)
# Out:
# <Axes: xlabel='day,time'>
